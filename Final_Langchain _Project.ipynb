# %%
# !pip install langchain transformers huggingface_hub pypdf python-docx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.3/336.3 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 13.0 MB/s eta 0:00:00
# ...

# %%
# !pip install -U langchain langchain-community langchain-core transformers huggingface_hub pypdf python-docx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 44.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.4/542.4 kB 33.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 102.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 646.8/646.8 kB 42.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 56.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 4.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.28
#     Uninstalling langchain-core-1.2.28:
#       Successfully uninstalled langchain-core-1.2.28
#   Attempting uninstall: huggingface_hub
# ...

# %%
# !pip uninstall -y langchain langchain-core langchain-community
# !pip install langchain==0.1.16 langchain-community==0.0.32
# Out:
# Found existing installation: langchain 1.2.15
# Uninstalling langchain-1.2.15:
#   Successfully uninstalled langchain-1.2.15
# Found existing installation: langchain-core 1.3.2
# Uninstalling langchain-core-1.3.2:
#   Successfully uninstalled langchain-core-1.3.2
# Found existing installation: langchain-community 0.4.1
# Uninstalling langchain-community-0.4.1:
#   Successfully uninstalled langchain-community-0.4.1
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.7/817.7 kB 24.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 72.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.1/303.1 kB 24.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.8/311.8 kB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 42.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.8 MB/s eta 0:00:00
# ...

# %%
# !pip install -U transformers

# %%
from transformers import pipeline

from langchain_community.llms import HuggingFacePipeline
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# %%
# !pip uninstall -y transformers
# !pip install transformers==4.41.2
# Out:
# Found existing installation: transformers 5.6.2
# Uninstalling transformers-5.6.2:
#   Successfully uninstalled transformers-5.6.2
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 78.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 37.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 100.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.12.0
#     Uninstalling huggingface_hub-1.12.0:
#       Successfully uninstalled huggingface_hub-1.12.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
# ...

# %%
from transformers import pipeline
from langchain_community.llms import HuggingFacePipeline

pipe = pipeline(
    "text-generation",
    model="tiiuae/falcon-7b-instruct",
    max_new_tokens=300
)

llm = HuggingFacePipeline(pipeline=pipe)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from pypdf import PdfReader
import docx
from google.colab import files
from pypdf import PdfReader

uploaded = files.upload()
file_name = list(uploaded.keys())[0]

def extract_text(file_name):
    text = ""

    try:
        # 📄 PDF
        if file_name.endswith(".pdf"):
            reader = PdfReader(file_name)
            for page in reader.pages:
                text += page.extract_text() or ""

        # 📝 DOCX
        elif file_name.endswith(".docx"):
            doc = docx.Document(file_name)
            for para in doc.paragraphs:
                text += para.text + "\n"

        else:
            print("Unsupported file format")

    except Exception as e:
        print("Error reading file:", e)

    return text
# Out:
#      <input type="file" id="files-63077044-692e-449e-9bbd-8ba79a928bd2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63077044-692e-449e-9bbd-8ba79a928bd2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
resume_text = extract_text(file_name)

# %%
job_desc = input("Paste Job Description here: ")
# Out:
# Paste Job Description here: We are looking for a Full Stack Developer with experience in React, Node.js, and MongoDB. The candidate should have knowledge of REST APIs, Git, and cloud platforms like AWS.

# %%
from langchain.prompts import PromptTemplate

template = """
You are a professional resume analyzer.

Analyze the resume based on the job description.

Resume:
{resume}

Job Description:
{jd}

Provide a clear structured answer:

Skills:
(list key skills)

Strengths:
(list strengths)

Weaknesses:
(list weaknesses)

Match Score:
(number out of 100)

Suggestions:
(improvements)
"""

prompt = PromptTemplate(
    input_variables=["resume", "jd"],
    template=template
)

# %%
from langchain.chains import LLMChain

chain = LLMChain(llm=llm, prompt=prompt)

# %%
short_resume = resume_text[:1200]

# %%
result = chain.invoke({
    "resume": short_resume,
    "jd": job_desc
})

print(result["text"])
# Out:
# 1. b.tech 2. b.tech 3. b.tech 4. match score 5. b.tech

# %%
print(result)
# Out:
# {'resume': 'Samruddhi Shingade\nKolhapur , Maharashtra – 416002 | +91 8999105495 |samruddhishingade02@gmail.com| Github/samruddhi | Leetcode/samruddhi | \nProfile \nB.Tech CSE(AIML) Engineer having a strong foundation of artificial intelligence and machine learning and full stack web development . Passionate about applying AI – driven solutions to real world problems . Eager to learn new technologies and tackle complex challenges . \nEducation \nD.K.T.E SOCIETY’S TEXTILE & ENGINEERING INSTITUTE , ICHALKARANJI \nB.Tech CSE (AIML ) ,  Current CGPA ( in 5th semester) : 9.07                                         2023 -2027      \nNew College , Kolhapur           \nHSC (12th grade )  :  73.33 %                                                                                           2022-2023\nPrivate High School , Kolhapur \nSSC ( 10th grade ) :  90.20 %                                                                         \t        2020-2021\nSkills \nTechnical Skills \nProgramming 
# ...
